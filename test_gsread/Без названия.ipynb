# %%
import pandas as pd
#https://docs.google.com/spreadsheets/d/e/2PACX-1vRRnOsDR9Nf96i_0MumrsVVTFyIdzpBkQRQdUaSQ7ZsSH9tNIRSxUqAEyR7pgQLvQ/pubhtml
data = pd.read_html('https://docs.google.com/spreadsheets/d/e/2PACX-1vRRnOsDR9Nf96i_0MumrsVVTFyIdzpBkQRQdUaSQ7ZsSH9tNIRSxUqAEyR7pgQLvQ/pubhtml?gid=658407717&single=true',encoding='utf-8', header=0, index_col=0)[0].fillna('Нет')
data
# Out:
#        Unnamed: 1  Unnamed: 2  Unnamed: 3           Unnamed: 4  \
# 1.0           Нет         Нет         Нет                  Нет
# 2.0           Нет         Нет         Нет                  Нет
# 3.0           Нет         Нет         Нет                  Нет
# 4.0   день недели         Нет        пара  время (начало пары)
# 5.0   день недели         Нет        пара  время (начало пары)
# 6.0   день недели         Нет        пара  время (начало пары)
# NaN           Нет         Нет         Нет                  Нет
# 7.0    16 октября  16 октября  16 октября           16 октября
# 8.0   понедельник         Нет         Нет                08:00
# 9.0   понедельник         Нет           1                08:50
# 10.0  понедельник         Нет           2                10:20
# 11.0  понедельник         Нет           3                11:50
# 12.0  понедельник         Нет         Нет                13:50
# 13.0  понедельник         Нет           4                14:40
# ...

# %%
# удаляем промежутчную ненужную строку
data = data.drop("Unnamed: 2", axis=1)

# %%
# удаляем первые 3 ненужные строки
data = data.drop([1.0,2.0,3.0,4.0])

# %%
data
# Out:
#        Unnamed: 1  Unnamed: 3           Unnamed: 4  \
# 5.0   день недели        пара  время (начало пары)
# 6.0   день недели        пара  время (начало пары)
# NaN           Нет         Нет                  Нет
# 7.0    16 октября  16 октября           16 октября
# 8.0   понедельник         Нет                08:00
# 9.0   понедельник           1                08:50
# 10.0  понедельник           2                10:20
# 11.0  понедельник           3                11:50
# 12.0  понедельник         Нет                13:50
# 13.0  понедельник           4                14:40
# 14.0  понедельник           5                16:10
# 15.0  понедельник           6                17:40
# 16.0   17 октября  17 октября           17 октября
# 17.0      вторник           1                08:00
# 18.0      вторник           2                09:45
# 19.0      вторник           3                11:30
# 20.0      вторник           4                13:45
# ...
